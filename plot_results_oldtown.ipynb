# %%
import numpy as np
import plotly.graph_objects as go

from orbslam_processor import ORBSLAMResults, ORBSLAMProcessor
from plotting_utils import create_scattermapbox, create_map_fig
from os import path

# TRAJECTORY_NAME = 'vabadusepst'
# TRAJECTORY_NAME = 'vabadusepst_self'
TRAJECTORY_NAME = 'oldtown'

processor = ORBSLAMProcessor(path.join('~/orbslam-out', TRAJECTORY_NAME))

# %%
processor.build_model()
# Out:
# Trial 200 Complete [00h 00m 01s]
# val_loss: 0.7042036652565002
#
# Best val_loss So Far: 0.037442391738295555
# Total elapsed time: 00h 03m 23s
# INFO:tensorflow:Oracle triggered exit
# Epoch 1/400
# 48/48 [==============================] - 0s 1ms/step - loss: 0.0985
# Epoch 2/400
# 48/48 [==============================] - 0s 1ms/step - loss: 0.0071
# Epoch 3/400
# 48/48 [==============================] - 0s 2ms/step - loss: 0.0053
# Epoch 4/400
# 48/48 [==============================] - 0s 2ms/step - loss: 0.0052
# Epoch 5/400
# 48/48 [==============================] - 0s 2ms/step - loss: 0.0049
# Epoch 6/400
# 48/48 [==============================] - 0s 2ms/step - loss: 0.0052
# Epoch 7/400
# 48/48 [==============================] - 0s 2ms/step - loss: 0.0041
# Epoch 8/400
# 48/48 [==============================] - 0s 2ms/step - loss: 0.0042
# Epoch 9/400
# 48/48 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 10/400
# 48/48 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 11/400
# 48/48 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 12/400
# 48/48 [==============================] - 0s 2ms/step - loss: 0.0042

# %%
processor.fit_trajectories()
# Out:
# 48/48 [==============================] - 0s 521us/step
# 412/412 [==============================] - 0s 528us/step
# 21/21 [==============================] - 0s 518us/step
# 135/135 [==============================] - 0s 509us/step
# 28/28 [==============================] - 0s 480us/step

# %%
fig_2d = processor.create_2d_plot_utm()
fig_2d.show()

# %%
fig_slam = processor.create_2d_plot_slam()
fig_slam.show()
